# %% [markdown]
# # Experiment 1: Collocation Point Sweep
#
# This notebook studies how the number of collocation points affects the accuracy of a Physics-Informed Neural Network for Burgers' equation.
#
# The supervised data size is fixed:
#
# - `N_u = 100`
#
# The network architecture is fixed:
#
# - 8 hidden layers
# - 20 neurons per hidden layer
# - `tanh` activation
#
# Only the number of physics collocation points changes:
#
# - `N_f = 0`
# - `N_f = 1000`
# - `N_f = 2500`
# - `N_f = 5000`
# - `N_f = 10000`
#
# The goal is to test whether enforcing the PDE residual at more points improves the final prediction.

# %% [markdown]
# # Imports

# %%
import os
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import scipy.io
from scipy.stats import qmc
import matplotlib.pyplot as plt

torch.set_default_dtype(torch.float64)

# %% [markdown]
# # Paths and folder

# %%
DATA_PATH = "../data/burgers_shock.mat"

RESULTS_DIR = "../results/experiment_1_collocation"
FIGURES_DIR = f"{RESULTS_DIR}/figures"
TABLES_DIR = f"{RESULTS_DIR}/tables"

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(FIGURES_DIR, exist_ok=True)
os.makedirs(TABLES_DIR, exist_ok=True)

print("Results will be saved to:", RESULTS_DIR)
# Out:
# Results will be saved to: ../results/experiment_1_collocation

# %% [markdown]
# # Load the reference data

# %%
data = scipy.io.loadmat(DATA_PATH)

t_grid = data["t"].flatten()[:, None]
x_grid = data["x"].flatten()[:, None]
Exact = data["usol"]  # shape: (256, 100)

X, T = np.meshgrid(x_grid, t_grid)

X_star = np.hstack((T.flatten()[:, None], X.flatten()[:, None]))
u_star = Exact.T.flatten()[:, None]

lb = X_star.min(0)
ub = X_star.max(0)

print("t_grid:", t_grid.shape)
print("x_grid:", x_grid.shape)
print("Exact:", Exact.shape)
print("X_star:", X_star.shape)
print("u_star:", u_star.shape)
print("lb:", lb)
print("ub:", ub)
# Out:
# t_grid: (100, 1)
# x_grid: (256, 1)
# Exact: (256, 100)
# X_star: (25600, 2)
# u_star: (25600, 1)
# lb: [ 0. -1.]
# ub: [0.99 1.  ]

# %% [markdown]
# # Experiment settings

# %%
N_f_values = [0, 1000, 2500, 5000, 10000]

N_u = 100
SEED = 1234

ADAM_STEPS = 2000
LBFGS_STEPS = 3000

layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]

print("N_f values:", N_f_values)
print("N_u fixed:", N_u)
print("Network layers:", layers)
# Out:
# N_f values: [0, 1000, 2500, 5000, 10000]
# N_u fixed: 100
# Network layers: [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]

# %% [markdown]
# ## Seed function

# %%
def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)

# %% [markdown]
# # Prepare NumPy training data

# %%
def prepare_training_data(N_u, N_f, seed=1234):
    """
    Creates NumPy arrays for:
    1. supervised initial/boundary data
    2. physics collocation points
    """

    set_seed(seed)

    # Initial condition: t = 0
    xx1 = np.hstack((X[0:1, :].T, T[0:1, :].T))
    uu1 = Exact[:, 0:1]

    # Boundary condition: x = -1
    xx2 = np.hstack((X[:, 0:1], T[:, 0:1]))
    uu2 = Exact[0:1, :].T

    # Boundary condition: x = 1
    xx3 = np.hstack((X[:, -1:], T[:, -1:]))
    uu3 = Exact[-1:, :].T

    # Combine all available initial/boundary points
    X_u_train_all = np.vstack([xx1, xx2, xx3])[:, [1, 0]]
    u_train_all = np.vstack([uu1, uu2, uu3])

    # Randomly select N_u supervised points
    idx = np.random.choice(X_u_train_all.shape[0], N_u, replace=False)

    X_u_train = X_u_train_all[idx, :]
    u_train = u_train_all[idx, :]

    # Create collocation points
    if N_f > 0:
        sampler = qmc.LatinHypercube(d=2, seed=seed)
        sample = sampler.random(n=N_f)

        X_f_train = lb + (ub - lb) * sample

        # Add supervised points to physics points
        X_f_train = np.vstack([X_f_train, X_u_train])
    else:
        X_f_train = np.empty((0, 2))

    return X_u_train, u_train, X_f_train

# %% [markdown]
# # Convert data to tensors

# %%
def convert_to_tensors(X_u_train, u_train, X_f_train):
    """
    Converts NumPy arrays into PyTorch tensors.

    t_u, x_u:
        supervised input points

    u_d:
        supervised target values

    t_f, x_f:
        collocation points for physics loss
    """

    tensors = {}

    tensors["t_u"] = torch.tensor(X_u_train[:, 0:1], requires_grad=True)
    tensors["x_u"] = torch.tensor(X_u_train[:, 1:2], requires_grad=True)
    tensors["u_d"] = torch.tensor(u_train)

    tensors["t_f"] = torch.tensor(X_f_train[:, 0:1], requires_grad=True)
    tensors["x_f"] = torch.tensor(X_f_train[:, 1:2], requires_grad=True)

    return tensors

# %% [markdown]
# # PINN model

# %%
class PINN(nn.Module):
    def __init__(self, layers):
        super().__init__()

        self.lb_t = torch.tensor(lb)
        self.ub_t = torch.tensor(ub)

        self.linears = nn.ModuleList(
            [nn.Linear(layers[i], layers[i + 1]) for i in range(len(layers) - 1)]
        )

        for layer in self.linears:
            nn.init.xavier_normal_(layer.weight)
            nn.init.zeros_(layer.bias)

    def forward(self, t, x):
        X_input = torch.cat([t, x], dim=1)

        # Normalize input to [-1, 1]
        H = 2.0 * (X_input - self.lb_t) / (self.ub_t - self.lb_t) - 1.0

        for layer in self.linears[:-1]:
            H = torch.tanh(layer(H))

        output = self.linears[-1](H)

        return output

# %% [markdown]
# # Physics residual

# %%
def net_f(model, t, x):
    """
    Computes Burgers' equation residual:

    f = u_t + u*u_x - (0.01/pi)*u_xx

    For a correct solution, f should be close to zero.
    """

    u = model(t, x)

    u_t = torch.autograd.grad(
        u,
        t,
        grad_outputs=torch.ones_like(u),
        create_graph=True
    )[0]

    u_x = torch.autograd.grad(
        u,
        x,
        grad_outputs=torch.ones_like(u),
        create_graph=True
    )[0]

    u_xx = torch.autograd.grad(
        u_x,
        x,
        grad_outputs=torch.ones_like(u_x),
        create_graph=True
    )[0]

    f = u_t + u * u_x - (0.01 / np.pi) * u_xx

    return f

# %% [markdown]
# # Relative L2 error

# %%
def relative_l2_error(y_true, y_pred):
    return np.linalg.norm(y_true - y_pred, 2) / np.linalg.norm(y_true, 2)

# %% [markdown]
# # One experiment run

# %%
def run_experiment(N_f):
    print("=" * 70)
    print(f"Running experiment with N_f = {N_f}")
    print("=" * 70)

    set_seed(SEED)

    start_time = time.time()

    # 1. Prepare NumPy data
    X_u_train, u_train, X_f_train = prepare_training_data(
        N_u=N_u,
        N_f=N_f,
        seed=SEED
    )

    # 2. Convert NumPy data to PyTorch tensors
    tensors = convert_to_tensors(
        X_u_train=X_u_train,
        u_train=u_train,
        X_f_train=X_f_train
    )

    # 3. Create a fresh model
    model = PINN(layers)

    num_parameters = sum(p.numel() for p in model.parameters())

    def loss_fn():
        u_pred = model(tensors["t_u"], tensors["x_u"])
        mse_u = torch.mean((tensors["u_d"] - u_pred) ** 2)

        if tensors["t_f"].shape[0] == 0:
            mse_f = torch.tensor(0.0, dtype=torch.float64)
        else:
            f_pred = net_f(model, tensors["t_f"], tensors["x_f"])
            mse_f = torch.mean(f_pred ** 2)

        loss = mse_u + mse_f

        return loss, mse_u, mse_f

    # 4. Adam optimizer
    optimizer_adam = torch.optim.Adam(model.parameters(), lr=1e-3)

    for it in range(ADAM_STEPS):
        optimizer_adam.zero_grad()

        loss, mse_u, mse_f = loss_fn()
        loss.backward()

        optimizer_adam.step()

        if it % 100 == 0:
            print(
                f"Adam {it:5d} | "
                f"loss = {loss.item():.3e} | "
                f"mse_u = {mse_u.item():.3e} | "
                f"mse_f = {mse_f.item():.3e}"
            )

    # 5. L-BFGS optimizer
    optimizer_lbfgs = torch.optim.LBFGS(
        model.parameters(),
        lr=1.0,
        max_iter=LBFGS_STEPS,
        max_eval=LBFGS_STEPS + 1000,
        history_size=50,
        tolerance_grad=1e-9,
        tolerance_change=1e-12,
        line_search_fn="strong_wolfe"
    )

    counter = [0]

    def closure():
        optimizer_lbfgs.zero_grad()

        loss, mse_u, mse_f = loss_fn()
        loss.backward()

        counter[0] += 1

        if counter[0] % 100 == 0:
            print(
                f"L-BFGS {counter[0]:5d} | "
                f"loss = {loss.item():.3e} | "
                f"mse_u = {mse_u.item():.3e} | "
                f"mse_f = {mse_f.item():.3e}"
            )

        return loss

    optimizer_lbfgs.step(closure)

    # 6. Evaluate on full reference grid
    with torch.no_grad():
        t_test = torch.tensor(X_star[:, 0:1])
        x_test = torch.tensor(X_star[:, 1:2])
        u_pred = model(t_test, x_test).numpy()

    error = relative_l2_error(u_star, u_pred)

    final_loss, final_mse_u, final_mse_f = loss_fn()

    training_time = time.time() - start_time

    result = {
        "N_u": N_u,
        "N_f": N_f,
        "actual_physics_points": X_f_train.shape[0],
        "num_parameters": num_parameters,
        "relative_l2_error": error,
        "final_mse_u": final_mse_u.item(),
        "final_mse_f": final_mse_f.item(),
        "training_time_seconds": training_time
    }

    print("Finished experiment:")
    print(result)

    return result

# %% [markdown]
# # Run all experiments

# %%
results = []

for N_f in N_f_values:
    result = run_experiment(N_f)
    results.append(result)

df_results = pd.DataFrame(results)
df_results
# Out:
# ======================================================================
# Running experiment with N_f = 0
# ======================================================================
# Adam     0 | loss = 2.433e-01 | mse_u = 2.433e-01 | mse_f = 0.000e+00
# Adam   100 | loss = 8.680e-03 | mse_u = 8.680e-03 | mse_f = 0.000e+00
# Adam   200 | loss = 9.736e-04 | mse_u = 9.736e-04 | mse_f = 0.000e+00
# Adam   300 | loss = 3.265e-04 | mse_u = 3.265e-04 | mse_f = 0.000e+00
# Adam   400 | loss = 2.713e-04 | mse_u = 2.713e-04 | mse_f = 0.000e+00
# Adam   500 | loss = 2.410e-04 | mse_u = 2.410e-04 | mse_f = 0.000e+00
# Adam   600 | loss = 2.225e-04 | mse_u = 2.225e-04 | mse_f = 0.000e+00
# Adam   700 | loss = 2.127e-04 | mse_u = 2.127e-04 | mse_f = 0.000e+00
# Adam   800 | loss = 1.937e-04 | mse_u = 1.937e-04 | mse_f = 0.000e+00
# Adam   900 | loss = 1.560e-03 | mse_u = 1.560e-03 | mse_f = 0.000e+00
# Adam  1000 | loss = 1.723e-04 | mse_u = 1.723e-04 | mse_f = 0.000e+00
# Adam  1100 | loss = 1.589e-04 | mse_u = 1.589e-04 | mse_f = 0.000e+00
# Adam  1200 | loss = 1.713e-04 | mse_u = 1.713e-04 | mse_f = 0.000e+00
# Adam  1300 | loss = 1.424e-04 | mse_u = 1.424e-04 | mse_f = 0.000e+00
# Adam  1400 | loss = 1.301e-04 | mse_u = 1.301e-04 | mse_f = 0.000e+00
# Adam  1500 | loss = 1.185e-04 | mse_u = 1.185e-04 | mse_f = 0.000e+00
# Adam  1600 | loss = 1.212e-04 | mse_u = 1.212e-04 | mse_f = 0.000e+00
# Adam  1700 | loss = 1.079e-04 | mse_u = 1.079e-04 | mse_f = 0.000e+00
# Adam  1800 | loss = 9.782e-05 | mse_u = 9.782e-05 | mse_f = 0.000e+00
# Adam  1900 | loss = 8.876e-05 | mse_u = 8.876e-05 | mse_f = 0.000e+00
# L-BFGS   100 | loss = 3.149e-05 | mse_u = 3.149e-05 | mse_f = 0.000e+00
# L-BFGS   200 | loss = 8.002e-06 | mse_u = 8.002e-06 | mse_f = 0.000e+00
# L-BFGS   300 | loss = 3.551e-06 | mse_u = 3.551e-06 | mse_f = 0.000e+00
# L-BFGS   400 | loss = 8.879e-07 | mse_u = 8.879e-07 | mse_f = 0.000e+00
# L-BFGS   500 | loss = 5.760e-07 | mse_u = 5.760e-07 | mse_f = 0.000e+00
# L-BFGS   600 | loss = 1.782e-07 | mse_u = 1.782e-07 | mse_f = 0.000e+00
# L-BFGS   700 | loss = 1.781e-07 | mse_u = 1.781e-07 | mse_f = 0.000e+00
# L-BFGS   800 | loss = 1.780e-07 | mse_u = 1.780e-07 | mse_f = 0.000e+00
# Finished experiment:
# {'N_u': 100, 'N_f': 0, 'actual_physics_points': 0, 'num_parameters': 3021, 'relative_l2_error': np.float64(0.937779371065085), 'final_mse_u': 1.7798871641446497e-07, 'final_mse_f': 0.0, 'training_time_seconds': 2.4270777702331543}
# ======================================================================
# Running experiment with N_f = 1000
# ======================================================================
# Adam     0 | loss = 3.144e-01 | mse_u = 2.433e-01 | mse_f = 7.111e-02
# Adam   100 | loss = 1.118e-01 | mse_u = 8.909e-02 | mse_f = 2.273e-02
# Adam   200 | loss = 7.592e-02 | mse_u = 5.564e-02 | mse_f = 2.028e-02
# Adam   300 | loss = 5.814e-02 | mse_u = 4.137e-02 | mse_f = 1.676e-02
# Adam   400 | loss = 4.510e-02 | mse_u = 3.216e-02 | mse_f = 1.293e-02
# Adam   500 | loss = 3.569e-02 | mse_u = 2.441e-02 | mse_f = 1.127e-02
# Adam   600 | loss = 4.808e-02 | mse_u = 3.385e-02 | mse_f = 1.423e-02
# Adam   700 | loss = 2.567e-02 | mse_u = 1.747e-02 | mse_f = 8.192e-03
# Adam   800 | loss = 4.525e-02 | mse_u = 2.483e-02 | mse_f = 2.041e-02
# Adam   900 | loss = 1.989e-02 | mse_u = 1.354e-02 | mse_f = 6.354e-03
# Adam  1000 | loss = 1.515e-02 | mse_u = 9.675e-03 | mse_f = 5.480e-03
# Adam  1100 | loss = 1.208e-02 | mse_u = 7.294e-03 | mse_f = 4.787e-03
# Adam  1200 | loss = 6.008e-02 | mse_u = 4.734e-02 | mse_f = 1.274e-02
# Adam  1300 | loss = 4.878e-02 | mse_u = 3.907e-02 | mse_f = 9.709e-03
# Adam  1400 | loss = 4.624e-02 | mse_u = 3.688e-02 | mse_f = 9.366e-03
# Adam  1500 | loss = 4.454e-02 | mse_u = 3.565e-02 | mse_f = 8.894e-03
# Adam  1600 | loss = 4.299e-02 | mse_u = 3.431e-02 | mse_f = 8.679e-03
# Adam  1700 | loss = 3.884e-02 | mse_u = 3.086e-02 | mse_f = 7.979e-03
# Adam  1800 | loss = 3.482e-02 | mse_u = 2.782e-02 | mse_f = 7.005e-03
# Adam  1900 | loss = 3.298e-02 | mse_u = 2.631e-02 | mse_f = 6.676e-03
# L-BFGS   100 | loss = 4.071e-02 | mse_u = 3.168e-02 | mse_f = 9.026e-03
# L-BFGS   200 | loss = 3.152e-02 | mse_u = 2.474e-02 | mse_f = 6.786e-03
# L-BFGS   300 | loss = 2.947e-02 | mse_u = 2.345e-02 | mse_f = 6.024e-03
# L-BFGS   400 | loss = 2.832e-02 | mse_u = 2.298e-02 | mse_f = 5.337e-03
# L-BFGS   500 | loss = 2.741e-02 | mse_u = 2.241e-02 | mse_f = 4.999e-03
# L-BFGS   600 | loss = 2.663e-02 | mse_u = 2.140e-02 | mse_f = 5.232e-03
# L-BFGS   700 | loss = 2.604e-02 | mse_u = 2.084e-02 | mse_f = 5.202e-03
# L-BFGS   800 | loss = 2.515e-02 | mse_u = 2.021e-02 | mse_f = 4.939e-03
# L-BFGS   900 | loss = 2.403e-02 | mse_u = 1.935e-02 | mse_f = 4.682e-03
# L-BFGS  1000 | loss = 2.348e-02 | mse_u = 1.887e-02 | mse_f = 4.615e-03
# L-BFGS  1100 | loss = 2.254e-02 | mse_u = 1.808e-02 | mse_f = 4.467e-03
# L-BFGS  1200 | loss = 2.203e-02 | mse_u = 1.770e-02 | mse_f = 4.323e-03
# L-BFGS  1300 | loss = 2.144e-02 | mse_u = 1.698e-02 | mse_f = 4.462e-03
# L-BFGS  1400 | loss = 2.059e-02 | mse_u = 1.597e-02 | mse_f = 4.620e-03
# L-BFGS  1500 | loss = 1.920e-02 | mse_u = 1.502e-02 | mse_f = 4.185e-03
# L-BFGS  1600 | loss = 1.904e-02 | mse_u = 1.458e-02 | mse_f = 4.460e-03
# L-BFGS  1700 | loss = 1.721e-02 | mse_u = 1.299e-02 | mse_f = 4.223e-03
# L-BFGS  1800 | loss = 1.646e-02 | mse_u = 1.213e-02 | mse_f = 4.324e-03
# L-BFGS  1900 | loss = 1.564e-02 | mse_u = 1.165e-02 | mse_f = 3.995e-03
# L-BFGS  2000 | loss = 1.489e-02 | mse_u = 1.149e-02 | mse_f = 3.398e-03
# L-BFGS  2100 | loss = 1.437e-02 | mse_u = 1.098e-02 | mse_f = 3.392e-03
# L-BFGS  2200 | loss = 1.407e-02 | mse_u = 1.071e-02 | mse_f = 3.363e-03
# L-BFGS  2300 | loss = 1.355e-02 | mse_u = 1.023e-02 | mse_f = 3.318e-03
# L-BFGS  2400 | loss = 1.292e-02 | mse_u = 9.758e-03 | mse_f = 3.162e-03
# L-BFGS  2500 | loss = 1.253e-02 | mse_u = 9.337e-03 | mse_f = 3.194e-03
# L-BFGS  2600 | loss = 1.220e-02 | mse_u = 8.882e-03 | mse_f = 3.319e-03
# L-BFGS  2700 | loss = 1.192e-02 | mse_u = 8.802e-03 | mse_f = 3.122e-03
# L-BFGS  2800 | loss = 1.159e-02 | mse_u = 8.434e-03 | mse_f = 3.152e-03
# L-BFGS  2900 | loss = 1.126e-02 | mse_u = 8.277e-03 | mse_f = 2.978e-03
# L-BFGS  3000 | loss = 1.084e-02 | mse_u = 7.808e-03 | mse_f = 3.032e-03
# L-BFGS  3100 | loss = 1.047e-02 | mse_u = 7.414e-03 | mse_f = 3.059e-03
# L-BFGS  3200 | loss = 9.993e-03 | mse_u = 6.908e-03 | mse_f = 3.085e-03
# L-BFGS  3300 | loss = 9.688e-03 | mse_u = 6.741e-03 | mse_f = 2.948e-03
# L-BFGS  3400 | loss = 9.247e-03 | mse_u = 6.100e-03 | mse_f = 3.147e-03
# Finished experiment:
# {'N_u': 100, 'N_f': 1000, 'actual_physics_points': 1100, 'num_parameters': 3021, 'relative_l2_error': np.float64(0.8731848771898438), 'final_mse_u': 0.005941560655739677, 'final_mse_f': 0.0031489757893616603, 'training_time_seconds': 40.709900856018066}
# ======================================================================
# Running experiment with N_f = 2500
# ======================================================================
# Adam     0 | loss = 3.163e-01 | mse_u = 2.433e-01 | mse_f = 7.295e-02
# Adam   100 | loss = 1.110e-01 | mse_u = 8.835e-02 | mse_f = 2.267e-02
# Adam   200 | loss = 7.487e-02 | mse_u = 5.415e-02 | mse_f = 2.073e-02
# Adam   300 | loss = 5.616e-02 | mse_u = 3.943e-02 | mse_f = 1.673e-02
# Adam   400 | loss = 4.785e-02 | mse_u = 3.341e-02 | mse_f = 1.444e-02
# Adam   500 | loss = 4.221e-02 | mse_u = 2.746e-02 | mse_f = 1.475e-02
# Adam   600 | loss = 2.920e-02 | mse_u = 1.972e-02 | mse_f = 9.482e-03
# Adam   700 | loss = 3.389e-02 | mse_u = 1.454e-02 | mse_f = 1.936e-02
# Adam   800 | loss = 2.599e-02 | mse_u = 1.858e-02 | mse_f = 7.416e-03
# Adam   900 | loss = 2.185e-02 | mse_u = 1.492e-02 | mse_f = 6.927e-03
# Adam  1000 | loss = 2.238e-02 | mse_u = 1.245e-02 | mse_f = 9.934e-03
# Adam  1100 | loss = 1.573e-02 | mse_u = 1.043e-02 | mse_f = 5.299e-03
# Adam  1200 | loss = 1.248e-02 | mse_u = 7.388e-03 | mse_f = 5.092e-03
# Adam  1300 | loss = 1.086e-02 | mse_u = 5.971e-03 | mse_f = 4.887e-03
# Adam  1400 | loss = 9.727e-03 | mse_u = 5.091e-03 | mse_f = 4.636e-03
# Adam  1500 | loss = 8.795e-03 | mse_u = 4.486e-03 | mse_f = 4.309e-03
# Adam  1600 | loss = 7.961e-03 | mse_u = 4.009e-03 | mse_f = 3.952e-03
# Adam  1700 | loss = 7.133e-03 | mse_u = 3.570e-03 | mse_f = 3.563e-03
# Adam  1800 | loss = 6.809e-03 | mse_u = 3.221e-03 | mse_f = 3.588e-03
# Adam  1900 | loss = 5.962e-03 | mse_u = 3.062e-03 | mse_f = 2.900e-03
# L-BFGS   100 | loss = 2.743e-03 | mse_u = 1.590e-03 | mse_f = 1.153e-03
# L-BFGS   200 | loss = 1.975e-03 | mse_u = 1.284e-03 | mse_f = 6.901e-04
# L-BFGS   300 | loss = 1.643e-03 | mse_u = 1.157e-03 | mse_f = 4.852e-04
# L-BFGS   400 | loss = 1.390e-03 | mse_u = 9.682e-04 | mse_f = 4.218e-04
# L-BFGS   500 | loss = 7.259e-04 | mse_u = 3.378e-04 | mse_f = 3.881e-04
# L-BFGS   600 | loss = 3.346e-04 | mse_u = 1.321e-04 | mse_f = 2.025e-04
# L-BFGS   700 | loss = 2.212e-04 | mse_u = 5.495e-05 | mse_f = 1.662e-04
# L-BFGS   800 | loss = 1.443e-04 | mse_u = 3.588e-05 | mse_f = 1.084e-04
# L-BFGS   900 | loss = 1.083e-04 | mse_u = 2.754e-05 | mse_f = 8.072e-05
# L-BFGS  1000 | loss = 8.109e-05 | mse_u = 2.135e-05 | mse_f = 5.974e-05
# L-BFGS  1100 | loss = 6.523e-05 | mse_u = 1.878e-05 | mse_f = 4.645e-05
# L-BFGS  1200 | loss = 5.258e-05 | mse_u = 1.486e-05 | mse_f = 3.772e-05
# L-BFGS  1300 | loss = 4.347e-05 | mse_u = 1.335e-05 | mse_f = 3.012e-05
# L-BFGS  1400 | loss = 3.743e-05 | mse_u = 9.412e-06 | mse_f = 2.802e-05
# L-BFGS  1500 | loss = 3.336e-05 | mse_u = 8.129e-06 | mse_f = 2.523e-05
# L-BFGS  1600 | loss = 2.834e-05 | mse_u = 7.139e-06 | mse_f = 2.120e-05
# L-BFGS  1700 | loss = 2.464e-05 | mse_u = 5.448e-06 | mse_f = 1.919e-05
# L-BFGS  1800 | loss = 2.136e-05 | mse_u = 4.341e-06 | mse_f = 1.702e-05
# L-BFGS  1900 | loss = 1.928e-05 | mse_u = 4.315e-06 | mse_f = 1.496e-05
# L-BFGS  2000 | loss = 1.744e-05 | mse_u = 3.365e-06 | mse_f = 1.408e-05
# L-BFGS  2100 | loss = 1.558e-05 | mse_u = 2.426e-06 | mse_f = 1.315e-05
# L-BFGS  2200 | loss = 1.358e-05 | mse_u = 1.936e-06 | mse_f = 1.164e-05
# L-BFGS  2300 | loss = 1.216e-05 | mse_u = 1.641e-06 | mse_f = 1.052e-05
# L-BFGS  2400 | loss = 1.099e-05 | mse_u = 1.442e-06 | mse_f = 9.544e-06
# L-BFGS  2500 | loss = 9.914e-06 | mse_u = 1.138e-06 | mse_f = 8.776e-06
# L-BFGS  2600 | loss = 9.047e-06 | mse_u = 8.204e-07 | mse_f = 8.227e-06
# L-BFGS  2700 | loss = 8.493e-06 | mse_u = 6.800e-07 | mse_f = 7.813e-06
# L-BFGS  2800 | loss = 8.092e-06 | mse_u = 5.879e-07 | mse_f = 7.504e-06
# L-BFGS  2900 | loss = 7.685e-06 | mse_u = 5.036e-07 | mse_f = 7.182e-06
# L-BFGS  3000 | loss = 7.292e-06 | mse_u = 4.519e-07 | mse_f = 6.840e-06
# L-BFGS  3100 | loss = 6.843e-06 | mse_u = 3.837e-07 | mse_f = 6.460e-06
# L-BFGS  3200 | loss = 6.399e-06 | mse_u = 3.085e-07 | mse_f = 6.090e-06
# Finished experiment:
# {'N_u': 100, 'N_f': 2500, 'actual_physics_points': 2600, 'num_parameters': 3021, 'relative_l2_error': np.float64(0.008752968277481857), 'final_mse_u': 2.7744562576466063e-07, 'final_mse_f': 5.773547716295558e-06, 'training_time_seconds': 95.20403409004211}
# ======================================================================
# Running experiment with N_f = 5000
# ======================================================================
# Adam     0 | loss = 3.161e-01 | mse_u = 2.433e-01 | mse_f = 7.276e-02
# Adam   100 | loss = 1.114e-01 | mse_u = 8.825e-02 | mse_f = 2.315e-02
# Adam   200 | loss = 7.683e-02 | mse_u = 5.607e-02 | mse_f = 2.076e-02
# Adam   300 | loss = 5.638e-02 | mse_u = 3.998e-02 | mse_f = 1.640e-02
# Adam   400 | loss = 4.816e-02 | mse_u = 3.350e-02 | mse_f = 1.466e-02
# Adam   500 | loss = 3.921e-02 | mse_u = 2.758e-02 | mse_f = 1.163e-02
# Adam   600 | loss = 2.924e-02 | mse_u = 1.927e-02 | mse_f = 9.973e-03
# Adam   700 | loss = 2.760e-02 | mse_u = 1.911e-02 | mse_f = 8.485e-03
# Adam   800 | loss = 2.252e-02 | mse_u = 1.516e-02 | mse_f = 7.362e-03
# Adam   900 | loss = 1.928e-02 | mse_u = 1.239e-02 | mse_f = 6.884e-03
# Adam  1000 | loss = 1.681e-02 | mse_u = 1.043e-02 | mse_f = 6.386e-03
# Adam  1100 | loss = 1.344e-02 | mse_u = 7.887e-03 | mse_f = 5.550e-03
# Adam  1200 | loss = 1.143e-02 | mse_u = 6.289e-03 | mse_f = 5.141e-03
# Adam  1300 | loss = 9.908e-03 | mse_u = 5.381e-03 | mse_f = 4.527e-03
# Adam  1400 | loss = 9.600e-03 | mse_u = 5.596e-03 | mse_f = 4.004e-03
# Adam  1500 | loss = 9.689e-03 | mse_u = 3.556e-03 | mse_f = 6.132e-03
# Adam  1600 | loss = 6.650e-03 | mse_u = 2.829e-03 | mse_f = 3.821e-03
# Adam  1700 | loss = 5.383e-03 | mse_u = 2.504e-03 | mse_f = 2.879e-03
# Adam  1800 | loss = 6.420e-03 | mse_u = 2.295e-03 | mse_f = 4.125e-03
# Adam  1900 | loss = 4.278e-03 | mse_u = 1.765e-03 | mse_f = 2.513e-03
# L-BFGS   100 | loss = 9.207e-04 | mse_u = 3.131e-04 | mse_f = 6.075e-04
# L-BFGS   200 | loss = 4.646e-04 | mse_u = 1.737e-04 | mse_f = 2.909e-04
# L-BFGS   300 | loss = 3.046e-04 | mse_u = 1.055e-04 | mse_f = 1.991e-04
# L-BFGS   400 | loss = 2.232e-04 | mse_u = 8.806e-05 | mse_f = 1.351e-04
# L-BFGS   500 | loss = 1.581e-04 | mse_u = 6.350e-05 | mse_f = 9.456e-05
# L-BFGS   600 | loss = 1.108e-04 | mse_u = 3.587e-05 | mse_f = 7.497e-05
# L-BFGS   700 | loss = 8.395e-05 | mse_u = 2.713e-05 | mse_f = 5.683e-05
# L-BFGS   800 | loss = 7.115e-05 | mse_u = 2.561e-05 | mse_f = 4.554e-05
# L-BFGS   900 | loss = 5.998e-05 | mse_u = 2.253e-05 | mse_f = 3.745e-05
# L-BFGS  1000 | loss = 5.187e-05 | mse_u = 1.826e-05 | mse_f = 3.362e-05
# L-BFGS  1100 | loss = 5.250e-05 | mse_u = 8.792e-06 | mse_f = 4.370e-05
# L-BFGS  1200 | loss = 3.285e-05 | mse_u = 5.671e-06 | mse_f = 2.718e-05
# L-BFGS  1300 | loss = 2.805e-05 | mse_u = 3.384e-06 | mse_f = 2.466e-05
# L-BFGS  1400 | loss = 2.351e-05 | mse_u = 2.547e-06 | mse_f = 2.096e-05
# L-BFGS  1500 | loss = 2.097e-05 | mse_u = 2.104e-06 | mse_f = 1.886e-05
# L-BFGS  1600 | loss = 1.860e-05 | mse_u = 2.297e-06 | mse_f = 1.630e-05
# L-BFGS  1700 | loss = 1.707e-05 | mse_u = 1.945e-06 | mse_f = 1.513e-05
# L-BFGS  1800 | loss = 1.536e-05 | mse_u = 1.601e-06 | mse_f = 1.376e-05
# L-BFGS  1900 | loss = 1.397e-05 | mse_u = 1.498e-06 | mse_f = 1.247e-05
# L-BFGS  2000 | loss = 1.279e-05 | mse_u = 1.368e-06 | mse_f = 1.142e-05
# L-BFGS  2100 | loss = 1.143e-05 | mse_u = 1.110e-06 | mse_f = 1.032e-05
# L-BFGS  2200 | loss = 1.049e-05 | mse_u = 1.062e-06 | mse_f = 9.424e-06
# L-BFGS  2300 | loss = 9.289e-06 | mse_u = 9.876e-07 | mse_f = 8.301e-06
# L-BFGS  2400 | loss = 8.396e-06 | mse_u = 7.694e-07 | mse_f = 7.626e-06
# L-BFGS  2500 | loss = 7.545e-06 | mse_u = 8.675e-07 | mse_f = 6.678e-06
# L-BFGS  2600 | loss = 7.000e-06 | mse_u = 8.849e-07 | mse_f = 6.115e-06
# L-BFGS  2700 | loss = 6.562e-06 | mse_u = 9.023e-07 | mse_f = 5.660e-06
# L-BFGS  2800 | loss = 6.116e-06 | mse_u = 8.780e-07 | mse_f = 5.238e-06
# L-BFGS  2900 | loss = 5.847e-06 | mse_u = 7.710e-07 | mse_f = 5.076e-06
# L-BFGS  3000 | loss = 5.526e-06 | mse_u = 6.411e-07 | mse_f = 4.885e-06
# L-BFGS  3100 | loss = 5.085e-06 | mse_u = 5.964e-07 | mse_f = 4.489e-06
# L-BFGS  3200 | loss = 4.765e-06 | mse_u = 5.730e-07 | mse_f = 4.192e-06
# L-BFGS  3300 | loss = 4.471e-06 | mse_u = 5.015e-07 | mse_f = 3.969e-06
# Finished experiment:
# {'N_u': 100, 'N_f': 5000, 'actual_physics_points': 5100, 'num_parameters': 3021, 'relative_l2_error': np.float64(0.006906370356361091), 'final_mse_u': 4.964285714549508e-07, 'final_mse_f': 3.950744260675436e-06, 'training_time_seconds': 159.41630125045776}
# ======================================================================
# Running experiment with N_f = 10000
# ======================================================================
# Adam     0 | loss = 3.164e-01 | mse_u = 2.433e-01 | mse_f = 7.302e-02
# Adam   100 | loss = 1.116e-01 | mse_u = 8.855e-02 | mse_f = 2.302e-02
# Adam   200 | loss = 7.632e-02 | mse_u = 5.569e-02 | mse_f = 2.063e-02
# Adam   300 | loss = 5.693e-02 | mse_u = 4.049e-02 | mse_f = 1.644e-02
# Adam   400 | loss = 4.899e-02 | mse_u = 3.438e-02 | mse_f = 1.460e-02
# Adam   500 | loss = 4.183e-02 | mse_u = 2.894e-02 | mse_f = 1.290e-02
# Adam   600 | loss = 3.162e-02 | mse_u = 2.166e-02 | mse_f = 9.954e-03
# Adam   700 | loss = 2.283e-02 | mse_u = 1.355e-02 | mse_f = 9.280e-03
# Adam   800 | loss = 1.875e-02 | mse_u = 1.192e-02 | mse_f = 6.827e-03
# Adam   900 | loss = 1.785e-02 | mse_u = 9.593e-03 | mse_f = 8.262e-03
# Adam  1000 | loss = 1.296e-02 | mse_u = 7.269e-03 | mse_f = 5.693e-03
# Adam  1100 | loss = 1.058e-02 | mse_u = 5.821e-03 | mse_f = 4.760e-03
# Adam  1200 | loss = 1.238e-02 | mse_u = 6.626e-03 | mse_f = 5.750e-03
# Adam  1300 | loss = 7.530e-03 | mse_u = 3.983e-03 | mse_f = 3.547e-03
# Adam  1400 | loss = 6.338e-03 | mse_u = 3.211e-03 | mse_f = 3.127e-03
# Adam  1500 | loss = 9.617e-03 | mse_u = 3.117e-03 | mse_f = 6.500e-03
# Adam  1600 | loss = 6.250e-03 | mse_u = 2.680e-03 | mse_f = 3.570e-03
# Adam  1700 | loss = 5.806e-03 | mse_u = 2.470e-03 | mse_f = 3.337e-03
# Adam  1800 | loss = 3.996e-03 | mse_u = 1.837e-03 | mse_f = 2.159e-03
# Adam  1900 | loss = 3.440e-03 | mse_u = 1.737e-03 | mse_f = 1.703e-03
# L-BFGS   100 | loss = 1.409e-03 | mse_u = 5.170e-04 | mse_f = 8.920e-04
# L-BFGS   200 | loss = 6.340e-04 | mse_u = 2.215e-04 | mse_f = 4.125e-04
# L-BFGS   300 | loss = 4.150e-04 | mse_u = 1.354e-04 | mse_f = 2.795e-04
# L-BFGS   400 | loss = 3.101e-04 | mse_u = 9.713e-05 | mse_f = 2.130e-04
# L-BFGS   500 | loss = 2.379e-04 | mse_u = 7.671e-05 | mse_f = 1.612e-04
# L-BFGS   600 | loss = 1.658e-04 | mse_u = 5.044e-05 | mse_f = 1.153e-04
# L-BFGS   700 | loss = 1.247e-04 | mse_u = 3.682e-05 | mse_f = 8.788e-05
# L-BFGS   800 | loss = 1.006e-04 | mse_u = 2.619e-05 | mse_f = 7.444e-05
# L-BFGS   900 | loss = 8.361e-05 | mse_u = 1.890e-05 | mse_f = 6.471e-05
# L-BFGS  1000 | loss = 6.997e-05 | mse_u = 1.703e-05 | mse_f = 5.295e-05
# L-BFGS  1100 | loss = 5.765e-05 | mse_u = 1.114e-05 | mse_f = 4.651e-05
# L-BFGS  1200 | loss = 4.704e-05 | mse_u = 9.407e-06 | mse_f = 3.763e-05
# L-BFGS  1300 | loss = 4.037e-05 | mse_u = 8.001e-06 | mse_f = 3.237e-05
# L-BFGS  1400 | loss = 3.378e-05 | mse_u = 6.443e-06 | mse_f = 2.733e-05
# L-BFGS  1500 | loss = 2.891e-05 | mse_u = 4.678e-06 | mse_f = 2.423e-05
# L-BFGS  1600 | loss = 2.561e-05 | mse_u = 4.074e-06 | mse_f = 2.153e-05
# L-BFGS  1700 | loss = 2.332e-05 | mse_u = 2.842e-06 | mse_f = 2.048e-05
# L-BFGS  1800 | loss = 2.072e-05 | mse_u = 2.320e-06 | mse_f = 1.840e-05
# L-BFGS  1900 | loss = 1.869e-05 | mse_u = 1.900e-06 | mse_f = 1.679e-05
# L-BFGS  2000 | loss = 1.674e-05 | mse_u = 1.661e-06 | mse_f = 1.507e-05
# L-BFGS  2100 | loss = 1.461e-05 | mse_u = 1.448e-06 | mse_f = 1.316e-05
# L-BFGS  2200 | loss = 1.323e-05 | mse_u = 1.209e-06 | mse_f = 1.202e-05
# L-BFGS  2300 | loss = 1.148e-05 | mse_u = 7.494e-07 | mse_f = 1.073e-05
# L-BFGS  2400 | loss = 1.026e-05 | mse_u = 5.991e-07 | mse_f = 9.658e-06
# L-BFGS  2500 | loss = 9.552e-06 | mse_u = 5.524e-07 | mse_f = 9.000e-06
# L-BFGS  2600 | loss = 8.769e-06 | mse_u = 5.309e-07 | mse_f = 8.238e-06
# L-BFGS  2700 | loss = 8.070e-06 | mse_u = 4.625e-07 | mse_f = 7.608e-06
# L-BFGS  2800 | loss = 7.634e-06 | mse_u = 4.051e-07 | mse_f = 7.229e-06
# L-BFGS  2900 | loss = 6.976e-06 | mse_u = 4.022e-07 | mse_f = 6.574e-06
# L-BFGS  3000 | loss = 6.583e-06 | mse_u = 3.464e-07 | mse_f = 6.236e-06
# L-BFGS  3100 | loss = 6.184e-06 | mse_u = 3.487e-07 | mse_f = 5.835e-06
# L-BFGS  3200 | loss = 5.763e-06 | mse_u = 3.119e-07 | mse_f = 5.451e-06
# L-BFGS  3300 | loss = 5.330e-06 | mse_u = 3.515e-07 | mse_f = 4.979e-06
# Finished experiment:
# {'N_u': 100, 'N_f': 10000, 'actual_physics_points': 10100, 'num_parameters': 3021, 'relative_l2_error': np.float64(0.0049506223380298775), 'final_mse_u': 3.5516381604212325e-07, 'final_mse_f': 4.9060895792284e-06, 'training_time_seconds': 310.11318492889404}
#    N_u    N_f  actual_physics_points  num_parameters  relative_l2_error  \
# 0  100      0                      0            3021           0.937779
# 1  100   1000                   1100            3021           0.873185
# 2  100   2500                   2600            3021           0.008753
# 3  100   5000                   5100            3021           0.006906
# 4  100  10000                  10100            3021           0.004951
#
#     final_mse_u  final_mse_f  training_time_seconds
# 0  1.779887e-07     0.000000               2.427078
# 1  5.941561e-03     0.003149              40.709901
# 2  2.774456e-07     0.000006              95.204034
# 3  4.964286e-07     0.000004             159.416301
# 4  3.551638e-07     0.000005             310.113185

# %% [markdown]
# ## Save results table

# %%
results_path = f"{RESULTS_DIR}/collocation_sweep_results.csv"

df_results.to_csv(results_path, index=False)

print("Saved results to:", results_path)
# Out:
# Saved results to: ../results/experiment_1_collocation/collocation_sweep_results.csv

# %% [markdown]
# # Summary table

# %%
df_summary = df_results[
    [
        "N_u",
        "N_f",
        "actual_physics_points",
        "num_parameters",
        "relative_l2_error",
        "final_mse_u",
        "final_mse_f",
        "training_time_seconds"
    ]
].sort_values("N_f")

summary_path = f"{TABLES_DIR}/collocation_sweep_summary.csv"
df_summary.to_csv(summary_path, index=False)

df_summary
# Out:
#    N_u    N_f  actual_physics_points  num_parameters  relative_l2_error  \
# 0  100      0                      0            3021           0.937779
# 1  100   1000                   1100            3021           0.873185
# 2  100   2500                   2600            3021           0.008753
# 3  100   5000                   5100            3021           0.006906
# 4  100  10000                  10100            3021           0.004951
#
#     final_mse_u  final_mse_f  training_time_seconds
# 0  1.779887e-07     0.000000               2.427078
# 1  5.941561e-03     0.003149              40.709901
# 2  2.774456e-07     0.000006              95.204034
# 3  4.964286e-07     0.000004             159.416301
# 4  3.551638e-07     0.000005             310.113185

# %% [markdown]
# # Plot N_f vs Relative L2 error

# %%
df_plot = df_results.sort_values("N_f")

plt.figure(figsize=(7, 5))

plt.plot(
    df_plot["N_f"],
    df_plot["relative_l2_error"],
    marker="o"
)

plt.xlabel("Number of collocation points $N_f$")
plt.ylabel("Relative L2 error")
plt.title("Effect of Collocation Points on PINN Accuracy")
plt.grid(True)

figure_path = f"{FIGURES_DIR}/Nf_vs_relative_l2.png"
plt.savefig(figure_path, dpi=150, bbox_inches="tight")

plt.show()

print("Saved figure to:", figure_path)
# Out:
# Saved figure to: ../results/experiment_1_collocation/figures/Nf_vs_relative_l2.png

# %% [markdown]
# # Plot N_f vs Training time

# %%
df_plot = df_results.sort_values("N_f")

plt.figure(figsize=(7, 5))

plt.plot(
    df_plot["N_f"],
    df_plot["training_time_seconds"],
    marker="o"
)

plt.xlabel("Number of collocation points $N_f$")
plt.ylabel("Training time, seconds")
plt.title("Training Time vs Collocation Points")
plt.grid(True)

figure_path = f"{FIGURES_DIR}/Nf_vs_training_time.png"
plt.savefig(figure_path, dpi=150, bbox_inches="tight")

plt.show()

print("Saved figure to:", figure_path)
# Out:
# Saved figure to: ../results/experiment_1_collocation/figures/Nf_vs_training_time.png

# %% [markdown]
# # Conclusion
#
# This experiment tested how the number of collocation points affects PINN accuracy.
#
# The supervised training size was fixed at `N_u = 100`, and the network architecture was fixed at 8 hidden layers with 20 neurons per layer. Only `N_f` was changed.
#
# When `N_f = 0`, the model does not use the physics residual and behaves more like a standard neural network trained only on sparse initial and boundary data.
#
# As `N_f` increases, the model is forced to satisfy Burgers' equation at more points inside the domain. This should generally improve the relative L2 error, although the trend may not be perfectly monotonic because PINN training is sensitive to initialization and optimization.
#
# Training time is expected to increase as `N_f` increases because computing the PDE residual requires automatic differentiation at more points.
